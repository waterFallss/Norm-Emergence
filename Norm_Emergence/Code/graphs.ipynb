# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
weight_1 = [1, 0, 0, 0.5, 0.25, 0.25, 0, 0.33, 0.5, 0.5]
weight_2 = [0, 1, 0, 0.25, 0.25, 0.5, 0.5, 0.33, 0, 0.5]
weight_3 = [0, 0, 1, 0.25, 0.25, 0.5, 0.5, 0.33, 0, 0.5]

action_one = [0, 50, 19, 2, 32, 41, 47, 29, 1, 5]
action_two = [0, 47, 16, 1, 33, 39, 50, 25, 2, 5]
not_converged = [100, 3, 65, 97, 35, 20, 0, 46, 97, 92]
converged = []
for value in not_converged:
    converged.append(100-value)

results = []
for index in range(len(action_one)):
    results.append((weight_1[index], weight_2[index], weight_3[index], converged[index]))
    
convergences = np.array(converged + converged + converged)
weights = np.array(weight_1 + weight_2 + weight_3)
actions = np.array(['Action_One']*len(action_one) + action_two + action_two)

# %%
from scipy.interpolate import griddata

# %%
x = range(len(weight_1))
plt.plot(x, weight_1, color='blue')
plt.plot(x, weight_2, color='red')
plt.plot(x, weight_3, color='green')

# plt.fill_between(x, weight_1, weight_2, where=weight_1>=weight_2, facecolor='blue', interpolate=True)
# plt.fill_between(x, weight_1, weight_2, where=weight_1<=weight_2, facecolor='red', interpolate=True)
# plt.fill_between(x, weight_2, weight_3, where=weight_2>=weight_3, facecolor='red', interpolate=True)
# plt.fill_between(x, weight_2, weight_3, where=weight_2<=weight_3, facecolor='green', interpolate=True)

plt.show()

# %%
for i, output in enumerate(['action_one', 'action_two', 'not_converged']):
    heatmap_data = df.pivot_table(values=output, index='action_one', columns='actions_two', aggfunc='mean')
    sns.heatmap(heatmap_data, ax=axs[i], annot=True, cmap=cmap, fmt='.1f', linewidths=.5)
    axs[i].set_title(f'Heatmap of {output}', fontsize=16)
    axs[i].set_xlabel('x2', fontsize=14)
    axs[i].set_ylabel('action_two', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 for i, output in enumerate(['action_one', 'action_two', 'not_converged']):
# ----> 2     heatmap_data = df.pivot_table(values=output, index='action_one', columns='actions_two', aggfunc='mean')
#       3     sns.heatmap(heatmap_data, ax=axs[i], annot=True, cmap=cmap, fmt='.1f', linewidths=.5)
#       4     axs[i].set_title(f'Heatmap of {output}', fontsize=16)
#
# File c:\Users\reade\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:9496, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9479 @Substitution("")
#    9480 @Appender(_shared_docs["pivot_table"])
#    9481 def pivot_table(
#    (...)
#    9492     sort: bool = True,
#    9493 ) -> DataFrame:
# ...
